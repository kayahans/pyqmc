# %%
# Wavefunction generation
from pyscf import mcscf, fci, lib 
from pyscf import gto, scf, tools, dft
from pyscf.dft import numint
import api as pyq 
import matplotlib.pyplot as plt
import importlib
import os
import h5py
import pdb
import pyscf
import numpy as np
from pyscf.scf.hf import dump_scf_summary
print(pyq.__file__)
print(pyscf.__file__)
# Out:
# /Users/ksu/Documents/GitHub/pyqmc/pyqmc/api.py
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/__init__.py

# %%
# Compare VXC from user input and PYSCF

# %%
from math import pi
mol = gto.M(atom="H 0. 0. 0.; H 0. 0. 1.2", spin=2, basis=f'ccecpccpvdz', unit='bohr')
mf = scf.UKS(mol)
scf_checkfile = "scf.hdf5"


#User defined XC functional (Slater exchange only)
factor = -3.0/4.0 * (3.0 / pi)**(1.0/3.0)
power = 4.0/3.0
def eval_xc(rho, a=factor, p=power):
    exc = a * rho ** p
    vrho = a * p * rho ** (p-1.0)
    vxc = (vrho, None, None, None)
    fxc = None  # 2nd order functional derivative
    kxc = None  # 3rd order functional derivative
    return exc, vxc, fxc, kxc


def my_eval_xc(a,p):    
    def eval_xc(xc_code, rho, *args, **kwargs):
        exc = a * rho ** p
        vrho = a * p * rho ** (p-1.0)
        vxc = (vrho, None, None, None)
        fxc = None  # 2nd order functional derivative
        kxc = None  # 3rd order functional derivative
        return exc, vxc, fxc, kxc
    return eval_xc
mf = mf.define_xc_(my_eval_xc(factor,power), 'LDA')
mf.kernel()
# mf.kernel(dm, xc='LDA,VWN')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/th/ycprc3g104l98mlf5cj0pdts_3skv1/T/ipykernel_97464/1461504614.py in <module>
#      27     return eval_xc
#      28 mf = mf.define_xc_(my_eval_xc(factor,power), 'LDA')
# ---> 29 mf.kernel()
#      30 # mf.kernel(dm, xc='LDA,VWN')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/scf/hf.py in kernel(self, dm0, **kwargs)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/scf/hf.py in scf(self, dm0, **kwargs)
#    1694             self.converged, self.e_tot, \
#    1695                     self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1696                     kernel(self, self.conv_tol, self.conv_tol_grad,
#    1697                            dm0=dm0, callback=self.callback,
#    1698                            conv_check=self.conv_check, **kwargs)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/scf/hf.py in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     126
#     127     h1e = mf.get_hcore(mol)
# --> 128     vhf = mf.get_veff(mol, dm)
#     129     e_tot = mf.energy_tot(dm, h1e, vhf)
#     130     logger.info(mf, 'init E= %.15g', e_tot)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/dft/uks.py in get_veff(ks, mol, dm, dm_last, vhf_last, hermi)
#      49     else:
#      50         max_memory = ks.max_memory - lib.current_memory()[0]
# ---> 51         n, exc, vxc = ni.nr_uks(mol, ks.grids, ks.xc, dm, max_memory=max_memory)
#      52         logger.debug(ks, 'nelec by numeric integration = %s', n)
#      53         if ks.nlc or ni.libxc.is_nlc(ks.xc):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/dft/numint.py in nr_uks(ni, mol, grids, xc_code, dms, relativity, hermi, max_memory, verbose)
#    1276     if xctype == 'LDA':
#    1277         ao_deriv = 0
# -> 1278         for i, ao, mask, wv in block_loop(ao_deriv):
#    1279             _dot_ao_ao_sparse(ao, ao, wv[0,0], nbins, mask, pair_mask, ao_loc,
#    1280                               hermi, vmat[0,i])
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pyscf/dft/numint.py in block_loop(ao_deriv)
#    1267                 nelec[0,i] += den_a.sum()
#    1268                 nelec[1,i] += den_b.sum()
# -> 1269                 excsum[i] += numpy.dot(den_a, exc)
#    1270                 excsum[i] += numpy.dot(den_b, exc)
#    1271                 wv = weight * vxc
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (18696,) and (2,18696) not aligned: 18696 (dim 0) != 2 (dim 0)

# %%
mf.scf_summary
# Out:
# {'e1': -2.636210021867354,
#  'coul': 1.369865813598822,
#  'exc': -0.6843546298633597,
#  'nuc': 0.8333333333333334}

# %%
#Grid
size = 1000
pos = np.linspace([0.,0.,0.],[0.,0., 1.2], size)
r = np.linalg.norm(pos, axis=1)

# %%
#Overlaps
aox = dft.numint.eval_ao(mol, pos, deriv=2)
ao0 = aox[0]
ao1 = aox[1:4]
ao2 = aox[4:4]
orb_coeffs = mf.mo_coeff[0]

#Density Matrix
dm = mf.make_rdm1()

# %%
mo_value = np.einsum('ij,jk,k->ik', ao0, mf.mo_coeff, mf.mo_occ)
rho = np.einsum('ij,ji->i', mo_value, mo_value.T) 
exc_user, vxcs_user  = eval_xc(rho)[:2]
vxc_user = vxcs_user[0]

rho_orig = numint.eval_rho(mol, ao0, dm, xctype='LDA')
excd, vxcs  = dft.libxc.eval_xc('LDA,', rho)[:2]
vxc = vxcs[0]

# %%
#user VXC and PYSCF VXC
plt.scatter(r, vxc_user, label='vxc_user')
plt.scatter(r, vxc, label='vxc')
plt.legend()

# %%
#user EXC and PYSCF EXC
plt.scatter(r, exc_user, label='exc_user')
plt.scatter(r, excd, label='exc')
plt.legend()

# %%
#PYSCF EXC*rho and user EXC
plt.scatter(r, exc_user, label='exc_user')
plt.scatter(r, excd*rho, label='exc*rho')
plt.legend()

# %%
plt.scatter(r, exc_user/vxc_user/rho)

# %%
plt.scatter(r, excd/vxc)

# %%
# Use regular grid to calculate energies
mol = mf.mol
coords = mf.grids.coords
weights = mf.grids.weights
reg_grid = numint.eval_ao(mol, coords)

# %%
rho_reg = numint.eval_rho(mol, reg_grid, dm, xctype='LDA')
excd_reg, vxcs_reg  = dft.libxc.eval_xc('LDA,VWN', rho_reg)[:2]
print(np.einsum('i,i,i->', excd_reg, rho_reg, weights))
print(np.einsum('i,i,i->', vxcs_reg[0], rho_reg, weights))
# Out:
# -0.6843546298633653
# -0.8943012814962873

# %%
excd_reg_user, vxcs_reg_user  = eval_xc(rho_reg)[:2]
np.einsum('i,i,i->', excd_reg_user, rho_reg, weights)
# Out:
# -0.0776195151272708

# %%
nelec, exc2, vxc2 = dft.numint.nr_vxc(mol, mf.grids, 'lda,vwn', dm)
print(exc2)
# Out:
# -0.6843546298633597
